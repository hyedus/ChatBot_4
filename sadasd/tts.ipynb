# %%
pip install speechrecognition
# Out:
# ...
#   Using cached SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
# ...

# %%
import speech_recognition as sr
sr.__version__
# Out:
# '3.8.1'

# %%
pip install gTTS
# Out:
# ...
#   Using cached gTTS-2.1.1-py3-none-any.whl (25 kB)
# ...
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.  Downloading beautifulsoup4-4.9.1-py3-none-any.whl (115 kB)
# ...
#   Using cached requests-2.24.0-py2.py3-none-any.whl (61 kB)
# ...
# Processing c:\users\gram\appdata\local\pip\cache\wheels\c1\78\25\81270af5521d88ea8db7da5d4f64872673976eb9692bcb0c13\gtts_token-1.1.3-py3-none-any.whl
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...
#   Using cached urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# ...
#
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...

# %%
pip install pyttsx

# %%
conda install Pyaudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\gram\anaconda3\envs\chatbot
#
#   added / updated specs:
#     - pyaudio
#
#
# The following NEW packages will be INSTALLED:
#
#   portaudio          pkgs/main/win-64::portaudio-19.6.0-he774522_4
#   pyaudio            pkgs/main/win-64::pyaudio-0.2.11-py37he774522_2
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# ### 그러면 음성을 받고 음성을 처리 후 /command로 봇에 넘겨줘야 할듯?
# ### 만약에 음성으로 오늘 키워드라고 했을 때, string을 짤라서 단어들을 탐색하고
# ### 오늘 / 키워드라고 나왔을 때, 인자로 오늘 , 키워드를 넘겨줘서 인자를 prams에 알맞게 넣어서 query

# %% [markdown]
# # 파일을 이용한 STT

# %%
import IPython
IPython.display.Audio('start1.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pip install pydub

# %%
from pydub import AudioSegment

google_file = AudioSegment.from_file("start.wav")
type(google_file)
# Out:
# pydub.audio_segment.AudioSegment

# %%
from gtts import gTTS
text ="어떤 서비스를 이용하시겠습니까? 1번 뉴스 조회....2번 오늘의 이슈....3번 오늘의 인기검색어....4번 끝내기...번호를 말해주세요."

tts = gTTS(text=text, lang='ko')
tts.save("start110.mp3")

# %%
import playsound
 
playsound.playsound('start110.mp3', True)

# %%
import speech_recognition as sr

AUDIO_FILE = "start.wav"

r = sr.Recognizer()

with sr.AudioFile(AUDIO_FILE) as source:
    audio = r.record(source)  # 전체 audio file 읽기

# 구글 웹 음성 API로 인식하기 (하루에 제한 50회)
try:
    print("Google Speech Recognition thinks you said : " + r.recognize_google(audio, language='ko'))
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))
# Out:
# Google Speech Recognition thinks you said : 어떤 서비스를 이용하실 일본뉴스 2번 오늘의 이슈 3번 끝내기 말해 주세요

# %%
pip install AudioSegment
# Out:
# ...
#   Using cached audiosegment-0.23.0-py3-none-any.whl (34 kB)
# Processing c:\users\gram\appdata\local\pip\cache\wheels\11\f9\67\a3158d131f57e1c0a7d8d966a707d4a2fb27567a4fe47723ad\webrtcvad-2.0.10-cp37-cp37m-win_amd64.whl
# ...
#   Using cached pydub-0.24.1-py2.py3-none-any.whl (30 kB)
# ...

# %%
pip install playsound

# %% [markdown]
# # 마이크를 통한 STT

# %%
import speech_recognition as sr

# microphone에서 auido source를 생성합니다
r = sr.Recognizer()
with sr.Microphone() as source:
    print("Say something!")
    audio = r.listen(source)

# 구글 웹 음성 API로 인식하기 (하루에 제한 50회)
try:
    print("Google Speech Recognition thinks you said : " + r.recognize_google(audio, language='ko'))
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))
    
#파일 저장
with open("microphone-results.wav", "wb") as f:
    f.write(audio.get_wav_data())
    
    
restart = ['뭐라고', '다시','잘못들었어','잘','못']

print(r.recognize_google(audio, language='ko')[0])

if(r.recognize_google(audio, language='ko')[0] == '1') or  (r.recognize_google(audio, language='ko')[0] =='일'):
    print("1")
elif(r.recognize_google(audio, language='ko')[0] == '2') or (r.recognize_google(audio, language='ko')[0] =='이'):
    print("2")
elif(r.recognize_google(audio, language='ko')[0] == '3') or (r.recognize_google(audio, language='ko')[0] =='삼'):
    print("3")
elif(r.recognize_google(audio, language='ko')[0] == '4') or (r.recognize_google(audio, language='ko')[0] == '사'):
    print("exit")
else:
    t = r.recognize_google(audio, language='ko').split(' ')
    
    #print(t)
    
    for text in t:
        for i in restart:
            if(text == i):
                print("다시 말해주자")
                break
# Out:
# Say something!
# Google Speech Recognition thinks you said : 뭐라고

# %%
restart = ['뭐라고', '다시','잘못들었어','잘','못']

print(r.recognize_google(audio, language='ko')[0])

if(r.recognize_google(audio, language='ko')[0] == '1') or  (r.recognize_google(audio, language='ko')[0] =='일'):
    print("1")
elif(r.recognize_google(audio, language='ko')[0] == '2') or (r.recognize_google(audio, language='ko')[0] =='이'):
    print("2")
elif(r.recognize_google(audio, language='ko')[0] == '3') or (r.recognize_google(audio, language='ko')[0] =='삼'):
    print("3")
elif(r.recognize_google(audio, language='ko')[0] == '4') or (r.recognize_google(audio, language='ko')[0] == '사'):
    print("exit")
else:
    t = r.recognize_google(audio, language='ko').split(' ')
    
    #print(t)
    
    for text in t:
        for i in restart:
            if(text == i):
                print("다시 말해주자")
                break
# Out:
# 뭐
# 다시 말해주자

# %% [markdown]
# # 위에 String이나 파일을 기반으로 TTS

# %%
from gtts import gTTS

text = "어떤 서비스를 이용하시겠습니까? 1번 뉴스 조회 2번 오늘의 이슈 3번 오늘의 인기검색어 4번 끝내기 번호를 말해주세요."

# 위에 r.recognize_google(audio, language='ko') <- string 형식 가져오는게 좋을듯
tts = gTTS(text=text, lang='ko')
#tts.save('start2.mp3')

with open('1111.mp3','wb') as f:

# %%
##만약에 위에 STT에서 음성으로 오늘 키워드 입력 -> 여기에서는 text =  r.recognize_google(audio, language='ko') 
# r.recognize_google(audio, language='ko')은 사용자가 입력한 음성
# 이거를 text에 저장 후 먼저 단어를 분리
# ex ) 오늘 키워드 -> 오늘 / 키워드
# if 단어에 함수목록 ( keyword, search, hot_issue)가 있다면 command 함수를 봇서버에서 command 처리 하고 이거를 다시
# TTS 처리??
#챗봇 서버 켜놓은 상태에서 위에 코드들 실행가능?
